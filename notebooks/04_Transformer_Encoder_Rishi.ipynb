# %% [markdown]
# # ⚙️ C-MAPSS RUL Estimation & Predictive Maintenance
# ## Model: Transformer Encoder (Multi-Head Attention)
# **Assigned Team Member**: Rishi Khandelwal (Member 4)
# **Course**: ICT-4442 Deep Learning Mini Project
#
# ---
# ### 📌 Notebook Description
# Multi-Head Self-Attention sequence modeling and full architecture benchmark comparison.

# %%
import torch
import numpy as np
import pandas as pd
from src.train import train_model
from src.evaluate import run_full_evaluation
from notebooks.generate_summary_table import generate_results_table, plot_actual_vs_predicted_all

# %%
# 1. Train Transformer Encoder Model with Multi-Head Self-Attention (Member 4: Rishi Khandelwal)
results_trans = train_model(model_type='transformer', dataset_id='FD001', epochs=25, lr=1e-3)

# %%
# 2. Multi-Model Benchmark Comparison & Actual vs Predicted Visualization
generate_results_table()
plot_actual_vs_predicted_all()
