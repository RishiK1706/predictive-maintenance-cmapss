# %% [markdown]
# # ⚙️ C-MAPSS RUL Estimation & Predictive Maintenance
# ## Model: 1D Convolutional Neural Network (1D-CNN)
# **Assigned Team Member**: Sachith V P (Member 2)
# **Course**: ICT-4442 Deep Learning Mini Project
#
# ---
# ### 📌 Notebook Description
# Exploratory Data Analysis (EDA) and 1D-CNN feature extraction training.

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from src.data_loader import load_raw_data, get_informative_features
from notebooks.eda_and_plots import plot_sensor_trajectories, plot_rul_distribution

# %%
# 1. Exploratory Data Analysis & Sensor Degradation Plotting (Member 2: Sachith V P)
plot_sensor_trajectories()
plot_rul_distribution()

# %%
# 2. Train 1D Convolutional Neural Network (1D-CNN)
from src.train import train_model
results_cnn = train_model(model_type='cnn1d', dataset_id='FD001', epochs=25, lr=1e-3)
